# %%
import numpy as np
import pandas as pd

# %%
## Reading the CSVs
movie_titles_df = pd.read_csv('Title_basics.tsv', dtype={"isAdult": "string"}, sep='\t')
movie_ratings_df = pd.read_csv('Title_ratings.tsv', sep='\t')
#user_ratings_df = pd.DataFrame(np.load('User_ratings.npy'))

## convert loaded np array to pd dataframe
#user_ratings_df[['userID', 'titleID', 'rating', 'date']] = user_ratings_df[0].str.split(',', expand=True)
#user_ratings_df = user_ratings_df.drop(0, axis=1)

# %%
#movie_titles_df

# %%
#movie_ratings_df

# %%
movie_titles_df = movie_titles_df.drop(['originalTitle', 'isAdult', 'endYear'], axis=1)

# %%
## Dropping all rows where title value is not 'Movie' or 'tvMovie'
only_movie_titles_df = movie_titles_df.drop(movie_titles_df[movie_titles_df.titleType.isin(["tvEpisode", "videoGame", "video", "tvSpecial", "tvShort", "tv", "tvSeries", "tvMiniSeries", "tvPilot", "short"])].index)

# %%
## Dropping rows where genre value = \N (no genres)
only_movie_titles_df = only_movie_titles_df[only_movie_titles_df.genres != r'\N']

# %%
## Marging movie titles with movie ratings
movie_rating_merge_df = pd.merge(only_movie_titles_df, movie_ratings_df, on="tconst")

# %%
## Splitting the strings in 'genre' column into list of strings of the individual genres
movie_rating_merge_df["genres"] = movie_rating_merge_df.genres.apply(lambda x: x.split(","))

# %%
## Converting list to pd.Series before stack() breaks the pd.Series into a multi-index Series
genres = movie_rating_merge_df.genres.apply(pd.Series).stack()

## Creating a dummy multi-index dataframe where each genre is a column
genres = pd.get_dummies(genres)

## Collapse the dataframe
genres = genres.groupby(level=0).sum()

# %%
## merging the dummy dataframe with the movie_rating_merge_df dataframe
movie_rating_merge_df = pd.concat([movie_rating_merge_df, genres], axis=1)

# %%
## Creating new dataframes with minimum rating count breakpoints to be exported as seperate CSV files
title_merge_ratings_10 = movie_rating_merge_df[movie_rating_merge_df['numVotes'] > 10]
title_merge_ratings_100 = movie_rating_merge_df[movie_rating_merge_df['numVotes'] > 100]
title_merge_ratings_1000 = movie_rating_merge_df[movie_rating_merge_df['numVotes'] > 1000]
title_merge_ratings_10000 = movie_rating_merge_df[movie_rating_merge_df['numVotes'] > 10000]
title_merge_ratings_100000 = movie_rating_merge_df[movie_rating_merge_df['numVotes'] > 100000]
title_merge_ratings_500000 = movie_rating_merge_df[movie_rating_merge_df['numVotes'] > 500000]

# %%
title_merge_ratings_500000
# Out:
#            tconst titleType                    primaryTitle startYear  \
# 12252   tt0034583     movie                      Casablanca      1942
# 22712   tt0050083     movie                    12 Angry Men      1957
# 25784   tt0054215     movie                          Psycho      1960
# 30145   tt0060196     movie  The Good, the Bad and the Ugly      1966
# 31798   tt0062622     movie           2001: A Space Odyssey      1968
# ...           ...       ...                             ...       ...
# 306015  tt6966692     movie                      Green Book      2018
# 307352  tt7131622     movie   Once Upon a Time in Hollywood      2019
# 308733  tt7286456     movie                           Joker      2019
# 318986  tt8579674     movie                            1917      2019
# 321465  tt8946378     movie                      Knives Out      2019
#
#        runtimeMinutes                       genres  averageRating  numVotes  \
# 12252             102        [Drama, Romance, War]            8.5    578015
# 22712              96               [Crime, Drama]            9.0    801467
# 25784             109  [Horror, Mystery, Thriller]            8.5    679732
# 30145             161         [Adventure, Western]            8.8    769762
# 31798             149          [Adventure, Sci-Fi]            8.3    677625
# ...               ...                          ...            ...       ...
# 306015            130   [Biography, Comedy, Drama]            8.2    506565
# 307352            161              [Comedy, Drama]            7.6    761699
# 308733            122     [Crime, Drama, Thriller]            8.4   1321768
# 318986            119         [Action, Drama, War]            8.2    607576
# 321465            130       [Comedy, Crime, Drama]            7.9    713136
#
#         Action  Adult  ...  News  Reality-TV  Romance  Sci-Fi  Short  Sport  \
# 12252        0      0  ...     0           0        1       0      0      0
# 22712        0      0  ...     0           0        0       0      0      0
# 25784        0      0  ...     0           0        0       0      0      0
# 30145        0      0  ...     0           0        0       0      0      0
# 31798        0      0  ...     0           0        0       1      0      0
# ...        ...    ...  ...   ...         ...      ...     ...    ...    ...
# 306015       0      0  ...     0           0        0       0      0      0
# 307352       0      0  ...     0           0        0       0      0      0
# 308733       0      0  ...     0           0        0       0      0      0
# 318986       1      0  ...     0           0        0       0      0      0
# 321465       0      0  ...     0           0        0       0      0      0
#
#         Talk-Show  Thriller  War  Western
# 12252           0         0    1        0
# 22712           0         0    0        0
# 25784           0         1    0        0
# 30145           0         0    0        1
# 31798           0         0    0        0
# ...           ...       ...  ...      ...
# 306015          0         0    0        0
# 307352          0         0    0        0
# 308733          0         1    0        0
# 318986          0         0    1        0
# 321465          0         0    0        0
#
# [293 rows x 36 columns]

# %%
## Exporting the datasets as csv
#title_merge_ratings_10.to_csv('title_merge_ratings_10.csv')
#title_merge_ratings_100.to_csv('title_merge_ratings_100.csv')
#title_merge_ratings_1000.to_csv('title_merge_ratings_1000.csv')
#title_merge_ratings_10000.to_csv('title_merge_ratings_10000.csv')
#title_merge_ratings_100000.to_csv('title_merge_ratings_100000.csv')
#title_merge_ratings_500000.to_csv('title_merge_ratings_500000.csv')

# %%
# for col in title_merge_ratings_100000.columns:
#     print(col)

# %%
title_merge_ratings_100000
# Out:
#            tconst titleType        primaryTitle startYear runtimeMinutes  \
# 1427    tt0012349     movie             The Kid      1921             68
# 2226    tt0015864     movie       The Gold Rush      1925             95
# 2611    tt0017136     movie          Metropolis      1927            153
# 4384    tt0021749     movie         City Lights      1931             87
# 4574    tt0022100     movie                   M      1931            117
# ...           ...       ...                 ...       ...            ...
# 325705  tt9639470     movie  Last Night in Soho      2021            116
# 326442  tt9764362     movie            The Menu      2022            107
# 326486  tt9770150     movie           Nomadland      2020            107
# 326517  tt9777666     movie    The Tomorrow War      2021            138
# 327200  tt9893250     movie        I Care a Lot      2020            118
#
#                             genres  averageRating  numVotes  Action  Adult  \
# 1427       [Comedy, Drama, Family]            8.3    128131       0      0
# 2226    [Adventure, Comedy, Drama]            8.1    112861       0      0
# 2611               [Drama, Sci-Fi]            8.3    176697       0      0
# 4384      [Comedy, Drama, Romance]            8.5    186936       0      0
# 4574    [Crime, Mystery, Thriller]            8.3    160220       0      0
# ...                            ...            ...       ...     ...    ...
# 325705    [Drama, Horror, Mystery]            7.0    145516       0      0
# 326442  [Comedy, Horror, Thriller]            7.2    261809       0      0
# 326486                     [Drama]            7.3    166713       0      0
# 326517  [Action, Adventure, Drama]            6.5    210492       1      0
# 327200      [Comedy, Crime, Drama]            6.3    136072       0      0
#
#         ...  News  Reality-TV  Romance  Sci-Fi  Short  Sport  Talk-Show  \
# 1427    ...     0           0        0       0      0      0          0
# 2226    ...     0           0        0       0      0      0          0
# 2611    ...     0           0        0       1      0      0          0
# 4384    ...     0           0        1       0      0      0          0
# 4574    ...     0           0        0       0      0      0          0
# ...     ...   ...         ...      ...     ...    ...    ...        ...
# 325705  ...     0           0        0       0      0      0          0
# 326442  ...     0           0        0       0      0      0          0
# 326486  ...     0           0        0       0      0      0          0
# 326517  ...     0           0        0       0      0      0          0
# 327200  ...     0           0        0       0      0      0          0
#
#         Thriller  War  Western
# 1427           0    0        0
# 2226           0    0        0
# 2611           0    0        0
# 4384           0    0        0
# 4574           1    0        0
# ...          ...  ...      ...
# 325705         0    0        0
# 326442         1    0        0
# 326486         0    0        0
# 326517         0    0        0
# 327200         0    0        0
#
# [2247 rows x 36 columns]
